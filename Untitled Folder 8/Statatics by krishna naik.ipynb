# %% [markdown]
# # DAY 3

# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
import statistics

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
mean_total_bill = np.mean(df['total_bill'])
median_total_bill=np.median(df['total_bill'])
mode_total_bill = statistics.mode(df["total_bill"])
print("centre tendency of total_bill ")
print("mean_total_bill",mean_total_bill)
print("median_total_bill",median_total_bill)
print("mode_total_bill",mode_total_bill)
# Out:
# centre tendency of total_bill
# mean_total_bill 19.785942622950824
# median_total_bill 17.795
# mode_total_bill 13.42

# %%
import warnings
warnings.filterwarnings("ignore")
plt.style.use("ggplot")
sns.boxplot(df["total_bill"]);

# %%
sns.histplot(df["total_bill"],kde = True);

# %%
sns.displot(df["total_bill"], kde = True);

# %%
df2 = sns.load_dataset("iris")
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.displot(df2["sepal_length"], kde = True);

# %%
sns.countplot(df2["species"]);

# %%
#percentile

Q1,Q2 = np.percentile(df2["sepal_length"],[25,75])
print(Q1, Q2)
# Out:
# 5.1 6.4

# %% [markdown]
# # DAY 4

# %%
#outliers

dataset= [11,10,12,14,12,15,14,13,15,102,12,14,17,19,107, 10,13,12,14,12,108,12,11,14,13,15,10,15,12,10,14,13,15,10]
outlier = []
def removeoutliers(data):
    threshold = 3
    m = np.mean(data)
    std = np.std(data)
    
    for i in data:
        z = (i-m)/std
        
        if z>threshold:
            outlier.append(i)
            
    return outlier

removeoutliers(dataset)
# Out:
# [102, 107, 108]

# %%
#IQR

# 1. sort the data
# 2. calculate Q1 and Q3
# 3. IQR
# 4. lower fence and upper fence

# %%
dataset = sorted(dataset)
len(dataset)
# Out:
# 34

# %%
Q1, Q3 = np.percentile(dataset,[25,75])
Q1, Q3
# Out:
# (12.0, 15.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# 3.0

# %%
lf = Q1 - 1.5*IQR
uf = Q3 + 1.5*IQR
lf,uf
# Out:
# (7.5, 19.5)

# %%
outlier1 =[]
for i in dataset:
    if i<lf or i > uf:
        outlier1.append(i)
print(outlier1)
# Out:
# [102, 107, 108]

# %% [markdown]
# # DAY 6
#
# Suppose the IQ in a certain population is normally distributed with a mean of µ = 100 and standard deviation of σ = 15.
#
# A researcher wants to know if a new drug affects IQ levels, so he recruits 20 patients to try it and records their IQ levels.
#
# The following code shows how to perform a one sample z-test in Python to determine if the new drug causes a significant difference in IQ levels

# %%
from statsmodels.stats.weightstats import ztest as ztest

#enter IQ Levels for 20 patients

data = [88, 92, 94, 94, 96, 97, 97, 97, 99, 99, 105, 109, 109, 109, 110, 112, 112, 113, 114, 115]

ztest(data,value= 100)
# Out:
# (1.5976240527147705, 0.1101266701438426)

# %%
np.std(data)
# Out:
# 8.321508276748872

# %%
(np.mean(data)-100)/(np.std(data)/np.sqrt(len(data)))
# Out:
# 1.639127692855906

# %% [markdown]
# ## T test

# %%
ages=[10,20,35,50,28,40,55,18,16,55,30,25,43,18,30,28,14,24,16,17,32,35,26,27,65,18,43,23,21,20,19,70]

# %%
age_mean =np.mean(ages)
age_mean
# Out:
# 30.34375

# %%
sample_size =10
age_sample = np.random.choice(ages,sample_size)
age_sample
# Out:
# array([65, 26, 27, 30, 14, 16, 18, 65, 65, 23])

# %%
from scipy.stats import ttest_1samp
ttest_1samp(age_sample,30)
# Out:
# Ttest_1sampResult(statistic=0.7255478239335663, pvalue=0.4865527507335179)
