# %%
from matplotlib import pyplot as plt
import numpy as np
from matplotlib import style
style.use('seaborn-whitegrid')
fig = plt.figure()
ax = plt.axes()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(1,10,1000)
y=np.sin(x)
plt.title("practise")
plt.xlabel("xlabel")
plt.ylabel("ylabel")
style.use('ggplot')
plt.plot(x,y,color='red',linewidth=4)

# %%
x=np.linspace(1,10,1000)
y=np.sin(x)
plt.title("practise")
plt.xlabel("xlabel")
plt.ylabel("ylabel")
style.use('ggplot')
plt.hist(y,color='red',linewidth=2)
# Out:
# (array([143.,  63.,  70.,  70.,  67.,  67.,  70.,  77.,  95., 278.]),
#  array([-9.99999771e-01, -7.99999969e-01, -6.00000168e-01, -4.00000366e-01,
#         -2.00000565e-01, -7.63503449e-07,  1.99999038e-01,  3.99998839e-01,
#          5.99998641e-01,  7.99998442e-01,  9.99998244e-01]),
#  <BarContainer object of 10 artists>)

# %%
vs=np.random.RandomState(0)
x=vs.random(100)
y=vs.random(100)
c0=vs.rand(110)
s0=100*vs.rand(100)
plt.hist(x,bins=50,color='red',edgecolor='black')
# Out:
# (array([4., 1., 1., 2., 5., 4., 3., 3., 0., 2., 2., 0., 2., 2., 3., 3., 0.,
#         0., 3., 1., 2., 2., 3., 3., 0., 0., 3., 2., 4., 2., 3., 2., 3., 4.,
#         2., 1., 2., 1., 0., 3., 2., 2., 2., 1., 0., 1., 2., 2., 1., 4.]),
#  array([0.00469548, 0.02436904, 0.04404261, 0.06371618, 0.08338975,
#         0.10306331, 0.12273688, 0.14241045, 0.16208401, 0.18175758,
#         0.20143115, 0.22110472, 0.24077828, 0.26045185, 0.28012542,
#         0.29979898, 0.31947255, 0.33914612, 0.35881969, 0.37849325,
#         0.39816682, 0.41784039, 0.43751396, 0.45718752, 0.47686109,
#         0.49653466, 0.51620822, 0.53588179, 0.55555536, 0.57522893,
#         0.59490249, 0.61457606, 0.63424963, 0.6539232 , 0.67359676,
#         0.69327033, 0.7129439 , 0.73261746, 0.75229103, 0.7719646 ,
#         0.79163817, 0.81131173, 0.8309853 , 0.85065887, 0.87033243,
#         0.890006  , 0.90967957, 0.92935314, 0.9490267 , 0.96870027,
#         0.98837384]),
#  <BarContainer object of 50 artists>)
